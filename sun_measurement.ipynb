# %%
import numpy as np
import ugradio
#%matplotlib notebook
plt.ioff()
import matplotlib.pyplot as plt
import time
from astropy.time import Time
import datetime

# %%
npz = np.load("horizon(moon)_(mar17).npz")
plt.plot(npz['volts'][0],'k.-')
plt.show()

moon = np.load("horizon(moon)_(mar18).npz")
moon_volts = moon['volts']
moon_times = moon['unitimes']
plt.plot( moon_volts[0])
plt.title('Moon Mar 18 30 min')
plt.show()

np.shape(moon_volts)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# (1, 61)

# %%
cygnus = np.load("horizon(Cygnus)_(mar17).npz")
volts = cygnus["volts"]
times = cygnus["unitimes"]

for i in range(len(volts)):
    plt.plot(times[i], volts[i], label=np.float(i*0.5+2))

plt.legend()
plt.xlabel('Time [Unit time]')
plt.ylabel('Signal [Volts]')
plt.title('Cygnus A 3.18 2am-3pm')
#plt.xlim(5000,60000)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
sun = np.load("horizon(sun )_(mar19).npz")
sun_volts = sun['volts']
sun_times = sun['unitimes']
plt.plot(sun_times[0],sun_volts[0],'k.-')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
sun = np.load("horizon(sun)_(mar18).npz")
sun_volts = sun['volts']
sun_times = sun['unitimes']
plt.plot(sun_times[0],sun_volts[0],'k.-')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
moon = np.load("horizon(moon_2 )_(mar18).npz")
moon_volts = moon['volts']
moon_times = moon['unitimes']
plt.plot(moon_times[0],moon_volts[0],'k.-')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#len(moon_volts[0])
#moon_times[0][1]-moon_times[0][0]
#moon_times[0][2]-moon_times[0][1]
# Out:
# 30.01475715637207

# %%
plt.plot(utctime[0], sun_volts[0])
plt.xlabel('Time [Unit time]')
plt.ylabel('Signal [Volts]')
plt.title('Sun 3.18 5-7pm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-194-01ab3f6afb2f> in <module>()
# ----> 1 plt.plot(utctime[0], sun_volts[0])
#       2 plt.xlabel('Time [Unit time]')
#       3 plt.ylabel('Signal [Volts]')
#       4 plt.title('Sun 3.18 5-7pm')
#       5 plt.show()
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1812                     warnings.warn(msg % (label_namer, func.__name__),
#    1813                                   RuntimeWarning, stacklevel=2)
# -> 1814             return func(ax, *args, **kwargs)
#    1815         pre_doc = inner.__doc__
# ...

# %%
t = Time(sun_times, format = 'unix')

# %%
print(sun_times[0][0])
print(t[0][0])
# Out:
# 1552960934.07
# 1552960934.07

# %%
t2 = t.fits
t2[0][0]
# Out:
# '2019-03-19T02:02:14.069(UTC)'

# %%
utctime = []
for i in range(len(sun_times[0])):
    utc = (datetime.datetime.utcfromtimestamp(sun_times[0][i]).strftime('%Y-%m-%d %H:%M:%S'))
    pst = utc[i][12:]
    utctime.append(utc)

# %%
str(7 - np.int(utctime[0][12:13])) +(utctime[0][13:])
# Out:
# '5:02:14'

# %%
utctime[0]
# Out:
# '2019-03-19 02:02:14'

# %% [markdown]
# #### expected local fringe frequency

# %%
sun = np.load("horizon(sun )_(mar19).npz")
time = sun['unitimes'][0]
time[2]-time[1]
len(sun['volts'][0])
# Out:
# 61

# %%
sun = np.load("horizon(sun )_(mar19).npz")
voltage = np.fft.fft(sun['volts'][0])
power = np.abs(voltage)**2
freq = np.fft.fftfreq(len(power), 30)
plt.plot(freq,power,'k.-')

# %%
np.fft.fftfreq??

# %%
Bew = 20 #m
Bns = 0 #m
lmbd = 2.5 * 10^(-2) #m = 2.5cm
